# %% [markdown]
# # Data Generation
#
# Objective:
#
# Generate synthetic ad interaction data to investigate a simulated 20% CTR decline.
#
# Columns:
#
# - date
# - user_id
# - country
# - device
# - browser
# - campaign
# - impressions
# - clicks
# - purchases
# - page_load_time
# - revenue

# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(42)
n = 100000

# %%
dates = pd.date_range(
    start='2026-06-01',
    end='2026-06-30'
)

# %%
dates
# Out:
# DatetimeIndex(['2026-06-01', '2026-06-02', '2026-06-03', '2026-06-04',
#                '2026-06-05', '2026-06-06', '2026-06-07', '2026-06-08',
#                '2026-06-09', '2026-06-10', '2026-06-11', '2026-06-12',
#                '2026-06-13', '2026-06-14', '2026-06-15', '2026-06-16',
#                '2026-06-17', '2026-06-18', '2026-06-19', '2026-06-20',
#                '2026-06-21', '2026-06-22', '2026-06-23', '2026-06-24',
#                '2026-06-25', '2026-06-26', '2026-06-27', '2026-06-28',
#                '2026-06-29', '2026-06-30'],
#               dtype='datetime64[ns]', freq='D')

# %%
countries = ['France', 'Germany', 'UK', 'USA']

# %%
devices = ['Mobile', 'Desktop']

# %%
browsers = ['Chrome', 'Safari', 'Firefox']

# %%
campaigns = ['Fashion', 'Electronics', 'Travel', 'Sports']
